# %%
#slicing
str = "apna college"
print(str[1:5])
# Out:
# pna

# %%
#string function


str = " i am studying python from apna college"
print(str.endswith("ege"))
# Out:
# True

# %%
text= "i am a athelete "
text =text.capitalize()
print(text)
# Out:
# I am a athelete

# %%
text = "i am 4 times gold medalist"
print(text.replace("4", "7"))
# Out:
# i am 7 times gold medalist

# %%
text ="i am 4 times gold medalist, 2 times silver meadlist , 1 time bronze medalist"
print(text.find("times"))
# Out:
# 7

# %%
text ="i am 4 times gold medalist, 2 times silver meadlist , 1 time bronze medalist"
print(text.count("a"))
# Out:
# 4

# %%
# questions 
name = input ("name:")
print(name)
total_lenth= len(name)
print(total_lenth)
# Out:
# name: anushka
# anushka
# 7

# %%
text = "i earn $1400 in 2025 now i earn $ 5000"
print(text.count("$"))
# Out:
# 2

# %%
# conditional statements
light= input("light color :")

if(light=="red"):
    print("stop")
elif(light=="yellow"):
    print("wait")
elif(light=="green"):
    print("go")
else:
    print("light is broken")
# Out:
# light color : red
# stop

# %%
age= 16
if(age >= 18):
    print("can vote & apply for license")
elif(age<=18):
    print("cannot vote & not able for license")
# Out:
# cannot vote & not able for license

# %%
num = 18
if(num>= 18):
    print("greater than 18")
elif(num==18):
    print(" equal to 18")
# Out:
# greater than 18

# %%
marks = 67

if marks >= 90:
    print("A+")
    print("pass")
elif 80 <= marks < 90:
    print("A")
    print("pass")
elif 70 <= marks < 80:
    print("B+")
    print("pass")
elif 60 <= marks < 70:
    print("B")
    print("pass")
elif 50 <= marks < 60:
    print("C")
    print("pass")
else:
    print("fail, try again")
# Out:
# B
# pass

# %%
#practice question
num= int(input("enter your number:"))
rem=num%2
if(rem==0):
    print("even")
else:
    print("odd")
# Out:
# enter your number: 23
# odd

# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
c = int(input("enter third number:"))
d = int(input("enter fourth number:"))

if(a>=b and a>=c and a>=b):
    print("first num is largest,a")
elif(b>=c):
    print("second num is largest , b")
elif(c>=d):
    print("third num is largest,c")
else:
    print("fourth num is largest ,d")
# Out:
# enter first number: 23
# enter second number: 45
# enter third number: 56
# enter fourth number: 67
# fourth num is largest ,d

# %%
num = int(input("enter number:"))

if(num%7==0):
    print("it is a multiple of 7")
else:
    print("it is not a multiple of 7")
# Out:
# enter number: 42
# it is a multiple of 7
