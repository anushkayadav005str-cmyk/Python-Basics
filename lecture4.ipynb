# %%
# list

# list ek collection (group) hota hai jisme multiple items store kar sakte hai
       #featue:
      # square brakets [] use hota hai
      # change (modify) kart sakte hai -> mutable
    # diffrent data tupes rakh sakte hai

# %%
marks=[94.09, 45.90,87.45,34.98,45.56]
print(marks)
print(len(marks))
print(marks[0])
print(marks[1])
# Out:
# [94.09, 45.9, 87.45, 34.98, 45.56]
# 5
# 94.09
# 45.9

# %%
student=["karan",88.95,"delhi"]
print(student)
student[0]="arjun"
print(student)
# Out:
# ['karan', 88.95, 'delhi']
# ['arjun', 88.95, 'delhi']

# %%
#list_slicing
num=[83,45,67,83,87,90]
print(num[1:4])
# Out:
# [45, 67, 83]

# %%
a = [1, 2, 3]
a.append(4)

# %%
a = [1, 2, 3]
a.insert(1, 10)

# %%
a = [1, 2, 3]
a.remove(2)

# %%
a = [1, 2, 3]
a.pop(1)

# %%
a = [1, 2, 3]
a.clear()

# %%
a = [10, 20, 30]
print(a.index(20))
# Out:
# 1

# %%
a = [1, 2, 2, 3]
print(a.count(2))
# Out:
# 2

# %%
a = [3, 1, 2]
a.sort()

# %%
a = [1, 2, 3]
a.reverse()

# %%
a = [1, 2, 3]
b = a.copy()
