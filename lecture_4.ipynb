# %%
# list

# list ek collection (group) hota hai jisme multiple items store kar sakte hai
       #featue:
      # square brakets [] use hota hai
      # change (modify) kart sakte hai -> mutable
    # diffrent data tupes rakh sakte hai

# %%
marks=[94.09, 45.90,87.45,34.98,45.56]
print(marks)
print(len(marks))
print(marks[0])
print(marks[1])
# Out:
# [94.09, 45.9, 87.45, 34.98, 45.56]
# 5
# 94.09
# 45.9

# %%
student=["karan",88.95,"delhi"]
print(student)
student[0]="arjun"
print(student)
# Out:
# ['karan', 88.95, 'delhi']
# ['arjun', 88.95, 'delhi']

# %%
#list_slicing
num=[83,45,67,83,87,90]
print(num[1:4])
# Out:
# [45, 67, 83]

# %%
# list methods
list=[1,2,3]
list.append(4)
print(list)

# mutate karna kehte hai
# Out:
# [1, 2, 3, 4]

# %%
list= [3,4,5,5,6]
print(list.append(7))
print(list.sort(reverse=True))
print(list)
# Out:
# None
# None
# [7, 6, 5, 5, 4, 3]

# %%
list=["a","v","d"]
print(list.sort())
print(list)
# Out:
# None
# ['a', 'd', 'v']

# %%
list= ["a","f","r","t","p","u"]
list.reverse()
print(list)
# Out:
# ['u', 'p', 't', 'r', 'f', 'a']

# %%
list=[1,4,5,8,0,5,7,3]
list.insert(3,6)
print(list)
# Out:
# [1, 4, 5, 6, 8, 0, 5, 7, 3]

# %%
list=[1,4,5,3,8,0,5,7,3]
list.pop(3)
print(list)
# Out:
# [1, 4, 5, 8, 0, 5, 7, 3]

# %%
list=[1,4,5,8,0,5,8,7,3]
list.remove(8)
print(list)
# Out:
# [1, 4, 5, 0, 5, 8, 7, 3]
