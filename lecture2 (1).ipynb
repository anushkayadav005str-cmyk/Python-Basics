# %%
#strings
str1=" this is a string.\n we are creating it in python." 
print(str1)
str2= 'taekwondo'
str3=""" this is a string"""
# \n= is use to write code's output in another line
#\t= is use to give huge space between two sentences
# Out:
#  this is a string.
#  we are creating it in python.

# %%
#lenth
str1="anushka"
len1 = len(str1)
print(len1)

str2="yadav"
len2 = len(str2)
print(len2)

final_str= str1 + "#" + str2
print(final_str)
print(len(final_str))
# Out:
# 7
# 5
# anushka#yadav
# 13

# %%
#indexing
str="gold_mine"
print(str[6])
# Out:
# i

# %%
#slicing
str = "12.4567"
print(str[1:5])
# Out:
# 2.45

# %%
#string function


str = " i am studying python from apna college"
print(str.endswith("ege"))
# Out:
# True

# %%
text= "i am a athelete "
text =text.capitalize()
print(text)
# Out:
# I am a athelete

# %%
text = "i am 4 times gold medalist"
print(text.replace("4", "7"))
# Out:
# i am 7 times gold medalist

# %%
text ="i am 4 times gold medalist, 2 times silver meadlist , 1 time bronze medalist"
print(text.find("times"))
# Out:
# 7

# %%
text ="i am 4 times gold medalist, 2 times silver meadlist , 1 time bronze medalist"
print(text.count("a"))
# Out:
# 4
